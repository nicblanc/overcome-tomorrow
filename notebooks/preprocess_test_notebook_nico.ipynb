# %%
# %load_ext autoreload
# %autoreload 2
from overcome_tomorrow.ml_logic.preprocess import *
import pandas as pd
pd.set_option('display.max_columns', None)

from sklearn import set_config; set_config(display='diagram')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
activities_df = pd.read_csv("../raw_data/CleanedData/activities.csv")

# %%
activities_df.tail(50)[activities_df.tail(50)["sub_sport"] == "gravel_cycling"]
# Out:
#                       timestamp  total_anaerobic_training_effect  \
# 3322  2023-01-24 08:46:49+00:00                              0.2
# 3324  2022-02-14 16:28:56+00:00                              0.0
# 3333  2023-08-23 07:16:34+00:00                              0.6
# 3354  2022-04-12 16:26:19+00:00                              0.0
# 3357  2023-03-16 08:38:43+00:00                              0.3
#
#       enhanced_avg_speed  avg_stroke_distance  total_training_effect  \
# 3322               8.639                  NaN                    3.3
# 3324               8.018                  NaN                    2.0
# 3333               9.289                  NaN                    3.6
# 3354               7.907                  NaN                    1.2
# 3357               9.042                  NaN                    3.8
#
#       num_active_lengths  max_running_cadence  max_heart_rate       sub_sport  \
# ...

# %%
res = create_preproc_activity(activities_df).fit_transform(activities_df)
# Out:
# ✅ Preprocess successful

# %%
res.iloc[[3322, 3324, 3333, 3354,3357]]
# Out:
#       knn_imputer__207  knn_imputer__total_anaerobic_training_effect  \
# 3322         -0.260274                                           0.2
# 3324         -0.027397                                           0.0
# 3333         -0.589041                                           0.6
# 3354          0.260274                                           0.0
# 3357         -0.698630                                           0.3
#
#       knn_imputer__total_calories  knn_imputer__188  \
# 3322                     1.344920               0.0
# 3324                    -0.070856               0.0
# 3333                     1.840909               0.5
# 3354                    -0.021390              -0.5
# 3357                     1.610963               0.5
#
#       knn_imputer__enhanced_avg_speed  knn_imputer__training_load_peak  \
# 3322                         1.145516                         0.946880
# 3324                         1.042300                        -0.107827
# ...

# %%
full_proces = create_preproc_activity(activities_df)

# %%
full_proces
# Out:
# InvertableColumnTransformer(transformers=[('knn_imputer',
#                                            Pipeline(steps=[('knn_imputer',
#                                                             KNNImputer(n_neighbors=4)),
#                                                            ('robust_scaler',
#                                                             RobustScaler())]),
#                                            ['207',
#                                             'total_anaerobic_training_effect',
#                                             'total_calories', '188',
#                                             'enhanced_avg_speed',
#                                             'training_load_peak',
#                                             'avg_heart_rate', 'total_descent',
#                                             '178', 'total_distance',
#                                             'enhanced_max_speed',
# ...

# %%
garmin_data = merge_all_data("../raw_data/Wellness/","../raw_data/Fitness/", "../raw_data/Aggregator/")
# Out:
# ✅ ../raw_data/Wellness/ loaded
# ✅ Wellness cleaned
# ✅ ../raw_data/Fitness/ loaded
# ✅ Fitness cleaned
# /home/nico/code/nicblanc/overcome-tomorrow/overcome_tomorrow/utils/data.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_fitness_df["date"] = pd.to_datetime(
# /home/nico/code/nicblanc/overcome-tomorrow/overcome_tomorrow/utils/data.py:208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_fitness_df["date"] = pd.to_datetime(clean_fitness_df["date"])
# ...

# %%
garmin_data.to_csv("../raw_data/garmin_data.csv")

# %%
garmin_data_preprocess = create_preproc_garmin_data(garmin_data)
# Out:
# ✅ Preprocess successful

# %%
garmin_data_preprocess.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3445 entries, 2019-08-29 to 2024-03-16
# Data columns (total 66 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   knn_transformer__deepSleepSeconds                        3445 non-null   float64
#  1   knn_transformer__lightSleepSeconds                       3445 non-null   float64
#  2   knn_transformer__remSleepSeconds                         3445 non-null   float64
#  3   knn_transformer__awakeSleepSeconds                       3445 non-null   float64
#  4   knn_transformer__qualityScore                            3445 non-null   float64
#  5   knn_transformer__activityTrainingLoad                    3445 non-null   float64
#  6   knn_transformer__aerobicTrainingEffect                   3445 non-null   float64
# ...

# %%
preproc_garmin = create_preproc_garmin_data(garmin_data)

# %%
preproc_garmin
# Out:
# ColumnTransformer(transformers=[('knn_transformer',
#                                  Pipeline(steps=[('knn_imputer',
#                                                   KNNImputer(n_neighbors=4)),
#                                                  ('robust_scaler',
#                                                   RobustScaler())]),
#                                  Index(['deepSleepSeconds', 'lightSleepSeconds', 'remSleepSeconds',
#        'awakeSleepSeconds', 'qualityScore', 'activityTrainingLoad',
#        'aerobicTrainingEffect', 'anaerobicTrainingEffect', 'avgBikeCadence',
#        'avgHr', 'avgPower...
#       dtype='object')),
#                                 ('pipe_categorical',
#                                  Pipeline(steps=[('simple_imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('one_hot',
# ...
